# %%
#------------------------- Text steganography decoding -------------------------#

groub_1 = "IiSsHhLlCcFfWwPpVvXxJj"
groub_0 = "NnRrDdUuMmYyGgBbKkQqZz"
groub_special = "(/\*&^%$#@!+=-}{[]}<:>)"



secret_message_in_binary=''
print ('Please enter the cover text :  ')
text =input()
kk=len(text)
print ('\n',text)
text = text.split()
length = len (text)
string =' '.join([str(itm)for itm in text])
string=string.replace("  "," ")
length = len(string)
for i in range (length):
    if string[i] in groub_1:
        secret_message_in_binary = secret_message_in_binary + '1'
        print (string[i],'= 1')
    elif string[i] in groub_0:
        secret_message_in_binary = secret_message_in_binary + '0'
        print(string[i], '= 0')
secret_message = ''
print ('the secret message in binary  =  ' ,secret_message_in_binary)
length = len(secret_message_in_binary)
w = secret_message_in_binary
split_string = [w[i:i+5] for i in range(0, len(w), 5)]
print ('split the binary to 5 digit   = ' , split_string)
l = len(split_string)
print ('number of extractor letters = ', l,' number of letters in binary = ', l*5,' the text letter number = ',kk ,' letters')
s = secret_message_in_binary
#-------------- The stage of extracting the hidden letter inside the text cover --------------#
secret_letter =''
for i in range (len(s)):
    if s[0:4] == '1010':
        secret_letter = secret_letter + ' '
        s = s[4:]
    if s[0:4] == '1100':
        secret_letter = secret_letter + 'e'
        s = s[4:]
    if s[0:4] == '1011':
        secret_letter = secret_letter + 't'
        s = s[4:]
    if s[0:4] == '1001':
        secret_letter = secret_letter + 'a'
        s = s[4:]
    if s[0:4] == '0111':
        secret_letter = secret_letter + 'o'
        s = s[4:]
    if s[0:4] == '0110':
        secret_letter = secret_letter + 'i'
        s = s[4:]
    if s[0:4] == '0100':
        secret_letter = secret_letter + 'n'
        s = s[4:]
    if s[0:4] == '0011':
        secret_letter = secret_letter + 's'
        s = s[4:]
    if s[0:4] == '0010':
        secret_letter = secret_letter + 'r'
        s = s[4:]
    if s[0:4] == '0001':
        secret_letter = secret_letter + 'h'
        s = s[4:]
    if s[0:5] == '11111':
        secret_letter = secret_letter + 'd'
        s = s[5:]
    if s[0:5] == '11110':
        secret_letter = secret_letter + 'l'
        s = s[5:]
    if s[0:5] == '11100':
        secret_letter = secret_letter + 'u'
        s = s[5:]
    if s[0:5] == '11011':
        secret_letter = secret_letter + 'c'
        s = s[5:]
    if s[0:5] == '11010':
        secret_letter = secret_letter + 'm'
        s = s[5:]
    if s[0:5] == '10000':
        secret_letter = secret_letter + 'f'
        s = s[5:]
    if s[0:5] == '01011':
        secret_letter = secret_letter + 'y'
        s = s[5:]
    if s[0:5] == '01010':
        secret_letter = secret_letter + 'w'
        s = s[5:]
    if s[0:5] == '00001':
        secret_letter = secret_letter + 'g'
        s = s[5:]
    if s[0:6] == '111011':
        secret_letter = secret_letter + 'p'
        s = s[6:]
    if s[0:6] == '111010':
        secret_letter = secret_letter + 'b'
        s = s[6:]
    if s[0:6] == '100010':
        secret_letter = secret_letter + 'v'
        s = s[6:]
    if s[0:6] == '000001':
        secret_letter = secret_letter + 'k'
        s = s[6:]
    if s[0:6] == '000000':
        secret_letter = secret_letter + 'x'
        s = s[6:]
    if s[0:7] == '1000110':
        secret_letter = secret_letter + 'q'
        s = s[7:]
    if s[0:8] == '10001111':
        secret_letter = secret_letter + 'j'
        s = s[8:]
    if s[0:8] == '10001110':
        secret_letter = secret_letter + 'z'
        s = s[8:]
    k=k+1
print (secret_letter)
